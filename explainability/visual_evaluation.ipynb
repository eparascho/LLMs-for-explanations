# %% [markdown]
# This notebook contains the code for visualizing the results (or a part of them) of the 4 implemented XAI algorithms

# %%
import sys
import json
import pandas as pd
sys.path.append('../')
from functions.visualizations import explainability_barplot

# %% [markdown]
# ##### Visualize the global lime explanation

# %%
# load lime data
with open('../data/explainability_output/global_30000_lime.json', 'r') as file:
    data = json.load(file)
data = pd.DataFrame([data]).T.reset_index().rename(columns = {'index':'feature', 0:'value'})
data
# Out:
#                       feature     value
# 0           sedentary_minutes -0.267820
# 1        minutes_below_zone_1  0.205067
# 2      lightly_active_minutes  0.169061
# 3             exertion_points  0.114464
# 4                sleep_points  0.093214
# 5                   step_goal  0.050660
# 6   moderately_active_minutes  0.016523
# 7                    altitude  0.009196
# 8                    calories -0.000440
# 9           minutes_in_zone_2 -0.007879
# 10        very_active_minutes  0.003921
# 11          minutes_in_zone_1  0.007163
# 12          minutes_in_zone_3  0.000062
# 13                      steps -0.000462
# 14             sleep_duration -0.000048
# 15          exercise_duration -0.000677
# 16                  exercises -0.001264

# %%
explainability_barplot(data, 'lime')

# %% [markdown]
# ##### Visualize the global coefficients explanation

# %%
# load coefficients data
with open('../data/explainability_output/global_coefficients.json', 'r') as file:
    data = json.load(file)
data = pd.DataFrame([data]).T.reset_index().rename(columns = {'index':'feature', 0:'value'})
data
# Out:
#                       feature      value
# 0             exertion_points   8.500879
# 1                   step_goal   5.017068
# 2        minutes_below_zone_1  12.645444
# 3           minutes_in_zone_1   0.904821
# 4                       steps  -0.061258
# 5         very_active_minutes   1.396713
# 6           minutes_in_zone_2  -3.598501
# 7           minutes_in_zone_3  -0.162295
# 8                    altitude   1.738288
# 9      lightly_active_minutes  11.978794
# 10  moderately_active_minutes   3.689641
# 11          sedentary_minutes -15.933499
# 12                  exercises  -0.174829
# 13          exercise_duration  -0.034386
# 14               sleep_points   6.655460
# 15             sleep_duration   0.000000
# 16                   calories   0.026056

# %%
explainability_barplot(data, 'coefficients')

# %% [markdown]
# ##### Visualize the local counterafactual explanation

# %%
test_data = pd.read_pickle('../data/explainability_input/test_data.pkl')
test_data.drop(columns = ['id', 'date', 'cluster'], inplace = True)
pd.DataFrame(pd.DataFrame([test_data.iloc[0]]).T.reset_index().rename(columns = {'index':'feature', 0:'value'}))
# Out:
#                       feature     value
# 0             exertion_points  0.622928
# 1                   step_goal  0.000000
# 2        minutes_below_zone_1  0.936806
# 3           minutes_in_zone_1  0.081134
# 4                       steps  0.017563
# 5         very_active_minutes  0.080685
# 6           minutes_in_zone_2  0.000000
# 7           minutes_in_zone_3  0.000000
# 8                    altitude  0.000000
# 9      lightly_active_minutes  0.254701
# 10  moderately_active_minutes  0.083045
# 11          sedentary_minutes  0.495139
# 12                  exercises  0.074074
# 13          exercise_duration  0.001865
# 14               sleep_points  0.810469
# 15             sleep_duration  0.000000
# 16                   calories  0.029382

# %%
# load counterfactual data
with open('../data/explainability_output/local_0_counterfactual.json', 'r') as file:
    data = json.load(file)
data = pd.DataFrame([data]).T.reset_index().rename(columns = {'index':'feature', 0:'value'})
data
# Out:
#                       feature     value
# 0             exertion_points  0.622928
# 1                   step_goal  0.000000
# 2        minutes_below_zone_1  0.600000
# 3           minutes_in_zone_1  0.081134
# 4                       steps  0.017563
# 5         very_active_minutes  0.080685
# 6           minutes_in_zone_2  0.000000
# 7           minutes_in_zone_3  0.000000
# 8                    altitude  0.000000
# 9      lightly_active_minutes  0.254701
# 10  moderately_active_minutes  0.083045
# 11          sedentary_minutes  0.920139
# 12                  exercises  0.074074
# 13          exercise_duration  0.001865
# 14               sleep_points  0.810469
# 15                   calories  0.000000
