# %% [markdown]
# This notebook contains the code for visualizing various numerical features supporting clustering intepretation.

# %%
import sys
import pandas as pd
sys.path.append('../../')
from functions.visualizations import histogram, grouped_barchart

# %%
# read data
data = pd.read_pickle('../../data/labeling_visualizations/kmeans_categories_final_labeling.pkl')

# %%
# plot histograms
histogram(data, 'mindfulness_end_heart_rate')

# %%
# plot grouped bar charts
grouped_barchart(data, ['cluster', 'full_sleep_breathing_rate', 'deep_sleep_breathing_rate', 'light_sleep_breathing_rate', 'rem_sleep_breathing_rate'])
